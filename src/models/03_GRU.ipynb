# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os


# !pip install scikit_optimize
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.utils import use_named_args

from sklearn.impute import SimpleImputer
from sklearn.metrics import balanced_accuracy_score, precision_score, recall_score, accuracy_score
# !pip install -U mlxtend
from mlxtend.evaluate import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import callbacks, regularizers
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.layers import CuDNNGRU, Dense, BatchNormalization, Dropout, CuDNNLSTM, Flatten
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# Requirement already satisfied: scikit_optimize in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit_optimize) (0.21.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scikit_optimize) (1.17.4)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from scikit_optimize) (1.3.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.19.1->scikit_optimize) (0.14.1)
# Requirement already up-to-date: mlxtend in /usr/local/lib/python3.6/dist-packages (0.17.0)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from mlxtend) (42.0.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.21.3)
# Requirement already satisfied, skipping upgrade: joblib>=0.13.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.14.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.3.3)
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.25.3)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (3.1.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.17.4)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->mlxtend) (2.6.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->mlxtend) (2018.9)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.4.5)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.1.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24.2->mlxtend) (1.12.0)
# 1.15.0
# 2.2.4-tf

# %%
def load(path):
    from google.colab import drive
    drive.mount('/gdrive')
    data_dir = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/data/'
    with open(data_dir + path, 'rb') as handle:
        data = pickle.load(handle)
    return data

# %%
def save(path, data):
    from google.colab import drive
    drive.mount('/gdrive')
    data_dir = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/data/'
    with open(data_dir + path, 'wb') as handle:
        pickle.dump(data, handle)

# %%
model_path = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/models/gru.hdf5'
best_model_path = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/models/gru_BayOpt.hdf5'

# %%
# Load data
train_x, train_y, val_x, val_y, test_x, test_y = load('input/data_lookback_60.pickle')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Hiperparameters and their ranges
dim_learning_rate = Real(low=1e-5, high=2e-2, prior='log-uniform',
                         name='learning_rate')
dim_num_dense_nodes = Integer(low=8, high=128, name='num_dense_nodes')
dim_num_rnn_layers = Integer(low=0, high=2, name='num_rnn_layers')
dim_num_rnn_nodes = Integer(low=8, high=128, name='num_rnn_nodes')
dim_dropout_rate = Real(low=0, high=0.5, name='dropout_rate')

dimensions = [dim_learning_rate,
              dim_num_dense_nodes,
              dim_num_rnn_layers,
              dim_num_rnn_nodes,
              dim_dropout_rate]

default_parameters = [5e-4, 32, 1, 64, 0.3]

best_accuracy = 0.0
best_history = None

# %%
def create_model(learning_rate, num_rnn_layers, num_rnn_nodes,
                 num_dense_nodes, dropout_rate, input_shape):
    """
    Hyper-parameters:
    learning_rate:     Learning-rate for the optimizer.
    num_dense_layers:  Number of dense layers.
    num_dense_nodes:   Number of nodes in each dense layer.
    num_rnn_layers:    Number of rnn layers.
    num_rnn_nodes:     Number of nodes in each rnn layer.
    dropout-rate:      Rate of droping in each dropout layer.
    """
    num_dense_layers = 2
    # Start construction of a Keras Sequential model.
    model = Sequential()

    for i in range(num_rnn_layers):
        # Name of the layer. This is not really necessary
        # because Keras should give them unique names.
        name = 'layer_rnn_{0}'.format(i+1)

        # Add the RNN layer to the model.
        # This has two hyper-parameters we want to optimize:
        # The number of nodes and the activation function.
        model.add(CuDNNGRU(num_rnn_nodes,
                           return_sequences=True,
                           kernel_regularizer=regularizers.l2(),
                           activity_regularizer=regularizers.l2(),
                           input_shape=input_shape,
                           name=name))
        model.add(Dropout(dropout_rate))
        
    model.add(CuDNNGRU(num_rnn_nodes,
                       return_sequences=False,
                       kernel_regularizer=regularizers.l2(),
                       activity_regularizer=regularizers.l2(),
                       input_shape=input_shape,
                       name='layer_rnn_'+str(num_rnn_layers+1)))

    model.add(Dropout(dropout_rate))

    # Add fully-connected / dense layers.
    # The number of layers is a hyper-parameter we want to optimize.
    for i in range(num_dense_layers):
        # Name of the layer. This is not really necessary
        # because Keras should give them unique names.
        name = 'layer_dense_{0}'.format(i+1)

        # Add the dense / fully-connected layer to the model.
        # This has two hyper-parameters we want to optimize:
        # The number of nodes and the activation function.
        model.add(Dense(num_dense_nodes,
                        activation='relu',
                        kernel_regularizer=regularizers.l2(),
                        name=name))
        model.add(Dropout(dropout_rate))

    # Last fully-connected / dense layer with softmax-activation
    # for use in classification.
    model.add(Dense(1, activation='sigmoid'))
    
    # Use the Adam method for training the network.
    # We want to find the best learning-rate for the Adam method.
    optimizer = keras.optimizers.Adam(lr=learning_rate)
    
    # In Keras we need to compile the model so it can be trained.
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate,
            num_dense_nodes,
            num_rnn_layers, num_rnn_nodes,
            dropout_rate):
    """
    Hyper-parameters:
    learning_rate:     Learning-rate for the optimizer.
    num_dense_nodes:   Number of nodes in each dense layer.
    num_rnn_layers:    Number of rnn layers.
    num_rnn_nodes:     Number of nodes in each rnn layer.
    dropout-rate:      Rate of droping in each dropout layer.
    """

    global i
    print('index', i)
    i += 1

    # Print the hyper-parameters.
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_dense_nodes:', num_dense_nodes)
    print('num_rnn_layers:', num_rnn_layers)
    print('num_rnn_nodes:', num_rnn_nodes)
    print('dropout_rate', dropout_rate)
    
    verbose = 0

    es = callbacks.EarlyStopping(monitor='val_loss', verbose=verbose, patience=20, min_delta=0.0001) 
    mc = callbacks.ModelCheckpoint(model_path, monitor='val_acc', verbose=verbose, save_best_only=True)

    # Create the neural network with these hyper-parameters.
    model = create_model(learning_rate=learning_rate,
                         num_dense_nodes=num_dense_nodes,
                         num_rnn_layers=num_rnn_layers,
                         num_rnn_nodes=num_rnn_nodes,
                         dropout_rate=dropout_rate,
                         input_shape=(train_x.shape[-2:]))
    
    # print(model.summary())
   
    # Use Keras to train the model.
    with tf.device('/gpu:0'):  
        history = model.fit(train_x, train_y, epochs=150, verbose=verbose, validation_data=(val_x, val_y), batch_size=32, callbacks=[es, mc],
                            validation_steps=100)

    # Get the classification accuracy on the validation-set
    # after the last training-epoch.
    model = load_model(model_path)
    predictions = model.predict(test_x)
    predictions = (predictions > 0.5)
    accuracy = accuracy_score(test_y, predictions)
    print('Highest validation accuracy: {0:.2%}'.format(max(history.history['val_acc'])))

    # Print the classification accuracy.
    print("Accuracy: {0:.2%}".format(accuracy))
    print()
    print()

    # Save the model if it improves on the best-found performance.
    # We use the global keyword so we update the variable outside
    # of this function.
    global best_accuracy
    global best_history

    # If the classification accuracy of the saved model is improved ...
    if accuracy > best_accuracy:
        # Save the new model to harddisk.
        model.save(best_model_path)
        
        # Update the classification accuracy.
        best_accuracy = accuracy
        best_history = history

    # Delete the Keras model with these hyper-parameters from memory.
    del model
    
    # Clear the Keras session, otherwise it will keep adding new
    # models to the same TensorFlow graph each time we create
    # a model with a different set of hyper-parameters.
    tf.keras.backend.clear_session()
    tf.reset_default_graph()
    
    # NOTE: Scikit-optimize does minimization so it tries to
    # find a set of hyper-parameters with the LOWEST fitness-value.
    # Because we are interested in the HIGHEST classification
    # accuracy, we need to negate this number so it can be minimized.
    return -accuracy

# %%
i = 0
fitness(x=default_parameters)
# Out:
# index 0
# learning rate: 5.0e-04
# num_dense_nodes: 32
# num_rnn_layers: 1
# num_rnn_nodes: 64
# dropout_rate 0.3
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Highest validation accuracy: 68.02%
# Accuracy: 59.30%
# -0.5930232558139535

# %%
i = 0
search_result = gp_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='PI', # Expected Improvement.
                            n_calls=50,
                            x0=default_parameters)
# Out:
# index 0
# learning rate: 5.0e-04
# num_dense_nodes: 32
# num_rnn_layers: 1
# num_rnn_nodes: 64
# dropout_rate 0.3
# Highest validation accuracy: 66.86%
# Accuracy: 59.88%
#
#
# index 1
# learning rate: 1.5e-04
# num_dense_nodes: 109
# num_rnn_layers: 1
# num_rnn_nodes: 104
# dropout_rate 0.37559306198914616
# Highest validation accuracy: 87.79%
# Accuracy: 77.91%
#
#
# index 2
# learning rate: 3.4e-04
# num_dense_nodes: 44
# num_rnn_layers: 1
# num_rnn_nodes: 50
# dropout_rate 0.34485195507884814
# Highest validation accuracy: 67.44%
# Accuracy: 59.30%
#
#
# index 3
# learning rate: 7.2e-05
# num_dense_nodes: 54
# num_rnn_layers: 1
# num_rnn_nodes: 10
# dropout_rate 0.15352531464763972
# Highest validation accuracy: 54.65%
# Accuracy: 49.42%
#
#
# index 4
# learning rate: 1.2e-04
# num_dense_nodes: 41
# num_rnn_layers: 1
# num_rnn_nodes: 67
# dropout_rate 0.05319101408801076
# Highest validation accuracy: 86.63%
# Accuracy: 70.35%
#
#
# index 5
# learning rate: 1.2e-03
# num_dense_nodes: 92
# num_rnn_layers: 1
# num_rnn_nodes: 113
# dropout_rate 0.4558255924294112
# Highest validation accuracy: 68.60%
# Accuracy: 59.88%
#
#
# index 6
# learning rate: 5.9e-03
# num_dense_nodes: 49
# num_rnn_layers: 2
# num_rnn_nodes: 33
# dropout_rate 0.017445045717094824
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 7
# learning rate: 1.3e-04
# num_dense_nodes: 22
# num_rnn_layers: 2
# num_rnn_nodes: 114
# dropout_rate 0.15765840191885358
# Highest validation accuracy: 53.49%
# Accuracy: 53.49%
#
#
# index 8
# learning rate: 3.5e-05
# num_dense_nodes: 18
# num_rnn_layers: 1
# num_rnn_nodes: 53
# dropout_rate 0.049226029884142555
# Highest validation accuracy: 64.53%
# Accuracy: 51.74%
#
#
# index 9
# learning rate: 4.3e-03
# num_dense_nodes: 39
# num_rnn_layers: 2
# num_rnn_nodes: 19
# dropout_rate 0.486731255458833
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 10
# learning rate: 1.8e-02
# num_dense_nodes: 71
# num_rnn_layers: 1
# num_rnn_nodes: 118
# dropout_rate 0.19830954178946814
# Highest validation accuracy: 50.58%
# Accuracy: 50.00%
#
#
# index 11
# learning rate: 1.3e-04
# num_dense_nodes: 8
# num_rnn_layers: 1
# num_rnn_nodes: 118
# dropout_rate 0.0
# Highest validation accuracy: 88.95%
# Accuracy: 75.58%
#
#
# index 12
# learning rate: 2.0e-04
# num_dense_nodes: 128
# num_rnn_layers: 1
# num_rnn_nodes: 107
# dropout_rate 0.0
# Highest validation accuracy: 86.63%
# Accuracy: 70.35%
#
#
# index 13
# learning rate: 1.5e-04
# num_dense_nodes: 88
# num_rnn_layers: 1
# num_rnn_nodes: 128
# dropout_rate 0.47743654863907253
# Highest validation accuracy: 69.77%
# Accuracy: 61.05%
#
#
# index 14
# learning rate: 1.3e-04
# num_dense_nodes: 77
# num_rnn_layers: 1
# num_rnn_nodes: 102
# dropout_rate 0.2543659678599287
# Highest validation accuracy: 87.21%
# Accuracy: 75.00%
#
#
# index 15
# learning rate: 1.2e-04
# num_dense_nodes: 8
# num_rnn_layers: 1
# num_rnn_nodes: 98
# dropout_rate 0.12210880028637226
# Highest validation accuracy: 86.63%
# Accuracy: 75.00%
#
#
# index 16
# learning rate: 1.1e-04
# num_dense_nodes: 15
# num_rnn_layers: 1
# num_rnn_nodes: 98
# dropout_rate 0.0
# Highest validation accuracy: 88.37%
# Accuracy: 72.09%
#
#
# index 17
# learning rate: 1.2e-04
# num_dense_nodes: 14
# num_rnn_layers: 1
# num_rnn_nodes: 110
# dropout_rate 0.2707686309129582
# Highest validation accuracy: 88.37%
# Accuracy: 73.84%
#
#
# index 18
# learning rate: 1.3e-04
# num_dense_nodes: 19
# num_rnn_layers: 1
# num_rnn_nodes: 97
# dropout_rate 0.21521969903643054
# Highest validation accuracy: 89.53%
# Accuracy: 73.26%
#
#
# index 19
# learning rate: 1.3e-04
# num_dense_nodes: 106
# num_rnn_layers: 1
# num_rnn_nodes: 95
# dropout_rate 0.45336414318712925
# Highest validation accuracy: 70.35%
# Accuracy: 62.79%
#
#
# index 20
# learning rate: 1.6e-04
# num_dense_nodes: 117
# num_rnn_layers: 1
# num_rnn_nodes: 108
# dropout_rate 0.34593890588269777
# Highest validation accuracy: 87.21%
# Accuracy: 72.09%
#
#
# index 21
# learning rate: 1.4e-04
# num_dense_nodes: 14
# num_rnn_layers: 1
# num_rnn_nodes: 118
# dropout_rate 0.12306581977334127
# Highest validation accuracy: 87.21%
# Accuracy: 72.09%
#
#
# index 22
# learning rate: 1.4e-04
# num_dense_nodes: 13
# num_rnn_layers: 1
# num_rnn_nodes: 111
# dropout_rate 0.08774806527829218
# Highest validation accuracy: 88.37%
# Accuracy: 72.67%
#
#
# index 23
# learning rate: 1.4e-04
# num_dense_nodes: 98
# num_rnn_layers: 1
# num_rnn_nodes: 110
# dropout_rate 0.09247021430687408
# Highest validation accuracy: 88.37%
# Accuracy: 73.84%
#
#
# index 24
# learning rate: 1.4e-04
# num_dense_nodes: 126
# num_rnn_layers: 1
# num_rnn_nodes: 110
# dropout_rate 0.10453628756926793
# Highest validation accuracy: 87.79%
# Accuracy: 75.00%
#
#
# index 25
# learning rate: 1.4e-04
# num_dense_nodes: 84
# num_rnn_layers: 1
# num_rnn_nodes: 110
# dropout_rate 0.1147046577363066
# Highest validation accuracy: 87.21%
# Accuracy: 73.26%
#
#
# index 26
# learning rate: 1.4e-04
# num_dense_nodes: 114
# num_rnn_layers: 1
# num_rnn_nodes: 110
# dropout_rate 0.11907160630264813
# Highest validation accuracy: 86.63%
# Accuracy: 73.26%
#
#
# index 27
# learning rate: 1.4e-04
# num_dense_nodes: 114
# num_rnn_layers: 1
# num_rnn_nodes: 110
# dropout_rate 0.1259972869621484
# Highest validation accuracy: 88.37%
# Accuracy: 73.84%
#
#
# index 28
# learning rate: 3.6e-05
# num_dense_nodes: 22
# num_rnn_layers: 1
# num_rnn_nodes: 104
# dropout_rate 0.43550687122668685
# Highest validation accuracy: 67.44%
# Accuracy: 57.56%
#
#
# index 29
# learning rate: 1.5e-04
# num_dense_nodes: 122
# num_rnn_layers: 1
# num_rnn_nodes: 110
# dropout_rate 0.13694806116626068
# Highest validation accuracy: 87.21%
# Accuracy: 72.67%
#
#
# index 30
# learning rate: 1.4e-04
# num_dense_nodes: 126
# num_rnn_layers: 1
# num_rnn_nodes: 114
# dropout_rate 0.1252433475938459
# Highest validation accuracy: 87.79%
# Accuracy: 73.26%
#
#
# index 31
# learning rate: 1.1e-04
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.0
# Highest validation accuracy: 86.63%
# Accuracy: 75.00%
#
#
# index 32
# learning rate: 1.5e-04
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 108
# dropout_rate 0.20089848382516776
# Highest validation accuracy: 84.88%
# Accuracy: 70.93%
#
#
# index 33
# learning rate: 1.0e-04
# num_dense_nodes: 115
# num_rnn_layers: 1
# num_rnn_nodes: 128
# dropout_rate 0.0
# Highest validation accuracy: 87.79%
# Accuracy: 72.09%
#
#
# index 34
# learning rate: 1.3e-04
# num_dense_nodes: 8
# num_rnn_layers: 0
# num_rnn_nodes: 114
# dropout_rate 0.0
# Highest validation accuracy: 84.88%
# Accuracy: 73.84%
#
#
# index 35
# learning rate: 3.5e-04
# num_dense_nodes: 30
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.0
# Highest validation accuracy: 83.72%
# Accuracy: 73.26%
#
#
# index 36
# learning rate: 2.8e-05
# num_dense_nodes: 8
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.0
# Highest validation accuracy: 79.07%
# Accuracy: 70.93%
#
#
# index 37
# learning rate: 2.0e-02
# num_dense_nodes: 111
# num_rnn_layers: 0
# num_rnn_nodes: 8
# dropout_rate 0.0
# Highest validation accuracy: 83.14%
# Accuracy: 68.60%
#
#
# index 38
# learning rate: 2.0e-02
# num_dense_nodes: 32
# num_rnn_layers: 0
# num_rnn_nodes: 8
# dropout_rate 0.5
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 39
# learning rate: 3.8e-04
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 65
# dropout_rate 0.0
# Highest validation accuracy: 86.05%
# Accuracy: 73.26%
#
#
# index 40
# learning rate: 1.7e-03
# num_dense_nodes: 99
# num_rnn_layers: 0
# num_rnn_nodes: 8
# dropout_rate 0.0
# Highest validation accuracy: 83.72%
# Accuracy: 73.26%
#
#
# index 41
# learning rate: 2.1e-03
# num_dense_nodes: 33
# num_rnn_layers: 0
# num_rnn_nodes: 69
# dropout_rate 0.0
# Highest validation accuracy: 86.63%
# Accuracy: 68.60%
#
#
# index 42
# learning rate: 4.0e-04
# num_dense_nodes: 8
# num_rnn_layers: 0
# num_rnn_nodes: 8
# dropout_rate 0.0
# Highest validation accuracy: 81.98%
# Accuracy: 74.42%
#
#
# index 43
# learning rate: 1.1e-04
# num_dense_nodes: 28
# num_rnn_layers: 0
# num_rnn_nodes: 57
# dropout_rate 0.0
# Highest validation accuracy: 84.88%
# Accuracy: 71.51%
#
#
# index 44
# learning rate: 5.8e-04
# num_dense_nodes: 14
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.34508913562211846
# Highest validation accuracy: 84.30%
# Accuracy: 76.74%
#
#
# index 45
# learning rate: 4.2e-04
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.4487456525202509
# Highest validation accuracy: 84.30%
# Accuracy: 72.09%
#
#
# index 46
# learning rate: 7.1e-04
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.24246673533453447
# Highest validation accuracy: 83.72%
# Accuracy: 76.16%
#
#
# index 47
# learning rate: 1.4e-03
# num_dense_nodes: 8
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.34797033194122584
# Highest validation accuracy: 84.30%
# Accuracy: 77.91%
#
#
# index 48
# learning rate: 1.6e-03
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.3784763698145367
# Highest validation accuracy: 81.98%
# Accuracy: 76.16%
#
#
# index 49
# learning rate: 1.4e-03
# num_dense_nodes: 8
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.2644366813156303
# Highest validation accuracy: 85.47%
# Accuracy: 74.42%

# %%
dim_names = ['learning_rate', 'num_dense_nodes', 'num_rnn_layers', 'num_rnn_nodes', 'dropout_rate']
# best params
best_params = search_result.x
for k, v in zip(dim_names, best_params):
    print(k, ' -> ', v)

# highest accuracy value on test set
acc = round(-1 *search_result.fun, 2)
print('Best accuracy -> ', acc)
# Out:
# learning_rate  ->  0.00015295857183217706
# num_dense_nodes  ->  109
# num_rnn_layers  ->  1
# num_rnn_nodes  ->  104
# dropout_rate  ->  0.37559306198914616
# Best accuracy ->  0.78

# %%
plt.rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(20, 20))
_ = plot_objective(result=search_result, dimensions=dim_names)

# %%
fig1 = plt.figure(figsize=(20, 20))
_ = plot_evaluations(search_result, dimensions=dim_names)

# %%
plt.rcParams.update({'font.size': 12})
fig2 = plt.figure(figsize=(15, 8))
_ = plot_convergence(search_result)
_ = plt.ylabel('Minimalna wartosć funkcji celu po n krokach')
_ = plt.xlabel('Liczba kroków algorytmu optymalizacji')
_ = plt.title('')

# %%
model = load_model(best_model_path)
print(model.summary())
predictions = model.predict(test_x)
predictions = (predictions > 0.5)
predictions = [int(pred) for pred in predictions]
prec = precision_score(test_y, predictions)
rec = recall_score(test_y, predictions)
acc = accuracy_score(test_y, predictions)

print(f"Accuracy: {round(acc * 100,2)}%")
print(f"precision: {round(prec * 100,2)}%")
print(f"recall: {round(rec * 100,2)}%")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_rnn_1 (CuDNNGRU)       (None, 60, 104)           43992
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 104)           0
# _________________________________________________________________
# layer_rnn_2 (CuDNNGRU)       (None, 104)               65520
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 104)               0
# _________________________________________________________________
# layer_dense_1 (Dense)        (None, 109)               11445
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 109)               0
# _________________________________________________________________
# layer_dense_2 (Dense)        (None, 109)               11990
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 109)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 110
# =================================================================
# Total params: 133,057
# Trainable params: 133,057
# Non-trainable params: 0
# _________________________________________________________________
# None
# Accuracy: 77.91%
# precision: 77.27%
# recall: 79.07%

# %%
plt.rcParams.update({'font.size': 14})
cm = confusion_matrix(y_target=test_y, 
                    y_predicted=predictions)

fig, ax = plot_confusion_matrix(conf_mat=cm,
                                class_names=['Spadek', 'Wzrost'],
                                figsize=(6,6))
_ = plt.ylabel('Prawdziwa etykieta')
_ = plt.xlabel('Przewidziana etykieta')

# %%
model.evaluate(test_x, test_y, steps=10)
# Out:
# WARNING:tensorflow:When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 10/10 [==============================] - 0s 14ms/step - loss: 0.7945 - acc: 0.7791
# [0.7945116758346558, 0.7790698]

# %%
def plot_predictions(length=60):
    fig = plt.figure(figsize=(22,3))
    plt.plot(test_y[:length])
    plt.plot(np.array(predictions)[:length])
    plt.legend(['Rzeczywista', 'Predykcja'], loc=1)
    plt.xlabel('Krok czasowy')
    plt.ylabel('Klasa')
    plt.yticks([0, 1], ['Spadek', 'Wzrost'])

plot_predictions()

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch
    plt.figure(figsize=(10, 6))
    plt.xlabel('Epoch')
    plt.ylabel('Błąd')
    plt.plot(hist['epoch'], hist['loss'], linewidth=2, color='orange',
            label='Trening')
    plt.plot(hist['epoch'], hist['val_loss'], linewidth=2,
            label = 'Walidacja')
    plt.legend()

    plt.figure(figsize=(10, 6))
    plt.xlabel('Epoch')
    plt.ylabel('Dokładność')
    plt.plot(hist['epoch'], hist['acc'], linewidth=2, color='orange',
            label='Trening')
    plt.plot(hist['epoch'], hist['val_acc'], linewidth=2,
            label = 'Walidacja')
    plt.legend()

plot_history(best_history)

# %%
print(len(predictions))
save('predictions/gru.pickle', predictions)
# Out:
# 172
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
