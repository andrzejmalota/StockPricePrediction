# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os


# !pip install scikit_optimize
import skopt
from skopt import gp_minimize, forest_minimize
from skopt.space import Real, Categorical, Integer
from skopt.plots import plot_convergence
from skopt.plots import plot_objective, plot_evaluations
from skopt.utils import use_named_args

from sklearn.impute import SimpleImputer
from sklearn.metrics import balanced_accuracy_score, precision_score, recall_score, accuracy_score
# !pip install -U mlxtend
from mlxtend.evaluate import confusion_matrix
from mlxtend.plotting import plot_confusion_matrix

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import callbacks, regularizers
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.layers import CuDNNGRU, Dense, BatchNormalization, Dropout, CuDNNLSTM, Flatten
from tensorflow.keras.layers import Conv1D, MaxPooling1D, InputLayer
print(tf.__version__)
print(tf.keras.__version__)
# Out:
# Requirement already satisfied: scikit_optimize in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.6/dist-packages (from scikit_optimize) (1.3.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from scikit_optimize) (1.17.4)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.6/dist-packages (from scikit_optimize) (0.21.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.19.1->scikit_optimize) (0.14.1)
# Requirement already up-to-date: mlxtend in /usr/local/lib/python3.6/dist-packages (0.17.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.25.3)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (3.1.2)
# Requirement already satisfied, skipping upgrade: scipy>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.3.3)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (1.17.4)
# Requirement already satisfied, skipping upgrade: joblib>=0.13.2 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.14.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from mlxtend) (42.0.2)
# Requirement already satisfied, skipping upgrade: scikit-learn>=0.20.3 in /usr/local/lib/python3.6/dist-packages (from mlxtend) (0.21.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->mlxtend) (2.6.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->mlxtend) (2018.9)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.4.5)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.1.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.10.0)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.6.1->pandas>=0.24.2->mlxtend) (1.12.0)
# 1.15.0
# 2.2.4-tf

# %%
def load(path):
    from google.colab import drive
    drive.mount('/gdrive')
    data_dir = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/data/'
    with open(data_dir + path, 'rb') as handle:
        data = pickle.load(handle)
    return data

# %%
def save(path, data):
    from google.colab import drive
    drive.mount('/gdrive')
    data_dir = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/data/'
    with open(data_dir + path, 'wb') as handle:
        pickle.dump(data, handle)

# %%
model_path = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/models/conv_lstm.hdf5'
best_model_path = '/gdrive/My Drive/Studia/INZYNIERKA/StockPricePrediction/models/conv_lstm_BayOpt.hdf5'

# %%
# Load data
train_x, train_y, val_x, val_y, test_x, test_y = load('input/data_lookback_60.pickle')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
dim_learning_rate = Real(low=5e-5, high=1e-2, prior='log-uniform', name='learning_rate')
dim_num_dense_nodes = Integer(low=16, high=256, name='num_dense_nodes')
dim_num_rnn_layers = Integer(low=0, high=1, name='num_rnn_layers')
dim_num_rnn_nodes = Integer(low=16, high=256, name='num_rnn_nodes')
dim_dropout_rate = Real(low=0, high=0.5, name='dropout_rate')
dim_kernel_size = Integer(low=2, high=20, name='kernel_size')
dim_regularizer = Real(low=0.001, high=0.03, name='regularizer')

dimensions = [dim_learning_rate,
              dim_num_dense_nodes,
              dim_num_rnn_layers,
              dim_num_rnn_nodes,
              dim_dropout_rate,
              dim_kernel_size,
              dim_regularizer
              ]

default_parameters = [1e-3, 128, 0, 128, 0.4, 4, 0.02]

best_accuracy = 0.0
best_history = None

# %%
def create_model(learning_rate, num_rnn_layers, num_rnn_nodes,
                 num_dense_nodes, dropout_rate, regularizer, kernel_size, input_shape):
    """
    Hyper-parameters:
    learning_rate:     Learning-rate for the optimizer.
    num_dense_layers:  Number of dense layers.
    num_dense_nodes:   Number of nodes in each dense layer.
    num_rnn_layers:    Number of rnn layers.
    num_rnn_nodes:     Number of nodes in each rnn layer.
    dropout-rate:      Rate of droping in each dropout layer.
    """
    num_dense_layers = 1
    num_conv_layers = 1

    # Start construction of a Keras Sequential model.
    model = Sequential()

    # Add an input layer which is similar to a feed_dict in TensorFlow.
    # Note that the input-shape must be a tuple containing the image-size.
    model.add(InputLayer(input_shape=input_shape))

    # The input from MNIST is a flattened array with 784 elements,
    # but the convolutional layers expect images with shape (28, 28, 1)
    # model.add(Reshape(img_shape_full))

    # First convolutional layer.
    # There are many hyper-parameters in this layer, but we only
    # want to optimize the activation-function in this example.
    for i in range(num_conv_layers):

        name = 'layer_conv_{0}'.format(i+1)
        model.add(Conv1D(kernel_size=(kernel_size,), strides=1, filters=16, padding='same',
                        activation='relu', name=name,
                        kernel_regularizer=regularizers.l2(regularizer)),
                        # activity_regularizer=regularizers.l2(0.001)
                        )
    
    model.add(Dropout(dropout_rate))
    model.add(MaxPooling1D(pool_size=2, strides=2))
    

    for i in range(num_rnn_layers):
        # Name of the layer. This is not really necessary
        # because Keras should give them unique names.
        name = 'layer_rnn_{0}'.format(i+1)

        # Add the RNN layer to the model.
        # This has two hyper-parameters we want to optimize:
        # The number of nodes and the activation function.
        model.add(CuDNNLSTM(num_rnn_nodes,
                           return_sequences=True,
                           kernel_regularizer=regularizers.l2(regularizer),
                           activity_regularizer=regularizers.l2(regularizer/2),
                           name=name))
        model.add(Dropout(dropout_rate))
        
    model.add(CuDNNLSTM(num_rnn_nodes,
                       return_sequences=False,
                       kernel_regularizer=regularizers.l2(regularizer),
                       activity_regularizer=regularizers.l2(regularizer/2),
                       name='layer_rnn_'+str(num_rnn_layers+1)))

    model.add(Dropout(dropout_rate))

    # Add fully-connected / dense layers.
    # The number of layers is a hyper-parameter we want to optimize.
    for i in range(num_dense_layers):
        # Name of the layer. This is not really necessary
        # because Keras should give them unique names.
        name = 'layer_dense_{0}'.format(i+1)

        # Add the dense / fully-connected layer to the model.
        # This has two hyper-parameters we want to optimize:
        # The number of nodes and the activation function.
        model.add(Dense(num_dense_nodes,
                        activation='relu',
                        kernel_regularizer=regularizers.l2(regularizer),
                        # activity_regularizer=regularizers.l2(0.003),
                        name=name))
        model.add(Dropout(dropout_rate))

    # Last fully-connected / dense layer with softmax-activation
    # for use in classification.
    model.add(Dense(1, activation='sigmoid'))
    
    # Use the Adam method for training the network.
    # We want to find the best learning-rate for the Adam method.
    optimizer = keras.optimizers.Adam(lr=learning_rate, decay=1e-6)
    
    # In Keras we need to compile the model so it can be trained.
    model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    
    return model

# %%
@use_named_args(dimensions=dimensions)
def fitness(learning_rate, num_dense_nodes,
            num_rnn_layers, num_rnn_nodes,
            dropout_rate, regularizer, kernel_size):
    """
    Hyper-parameters:
    learning_rate:     Learning-rate for the optimizer.
    num_dense_nodes:   Number of nodes in each dense layer.
    num_rnn_layers:    Number of rnn layers.
    num_rnn_nodes:     Number of nodes in each rnn layer.
    dropout-rate:      Rate of droping in each dropout layer.
    """

    global i
    print('index', i)
    i += 1

    # Print the hyper-parameters.
    print('learning rate: {0:.1e}'.format(learning_rate))
    print('num_dense_nodes:', num_dense_nodes)
    print('num_rnn_layers:', num_rnn_layers)
    print('num_rnn_nodes:', num_rnn_nodes)
    print('dropout_rate', dropout_rate)
    print('regularizer:', regularizer)
    print('kernel_size', kernel_size)
    
    verbose = 0

    es = callbacks.EarlyStopping(monitor='val_acc', verbose=verbose, patience=20, min_delta=0.0001) 
    mc = callbacks.ModelCheckpoint(model_path, monitor='val_loss', verbose=verbose, save_best_only=True)

    # Create the neural network with these hyper-parameters.
    model = create_model(learning_rate=learning_rate,
                         num_dense_nodes=num_dense_nodes,
                         num_rnn_layers=num_rnn_layers,
                         num_rnn_nodes=num_rnn_nodes,
                         dropout_rate=dropout_rate,
                         regularizer=regularizer,
                         kernel_size=kernel_size,
                         input_shape=(train_x.shape[-2:]))
    
    # print(model.summary())
   
    # Use Keras to train the model.
    with tf.device('/gpu:0'):  
        history = model.fit(train_x, train_y, epochs=150, verbose=verbose, validation_data=(val_x, val_y), batch_size=32, callbacks=[es, mc],
                            validation_steps=100)

    # Get the classification accuracy on the validation-set
    # after the last training-epoch.
    model = load_model(model_path)
    predictions = model.predict(test_x)
    predictions = (predictions > 0.5)
    accuracy = accuracy_score(test_y, predictions)
    print('Highest validation accuracy: {0:.2%}'.format(max(history.history['val_acc'])))

    # Print the classification accuracy.
    print("Accuracy: {0:.2%}".format(accuracy))
    print()
    print()

    # Save the model if it improves on the best-found performance.
    # We use the global keyword so we update the variable outside
    # of this function.
    global best_accuracy
    global best_history

    # If the classification accuracy of the saved model is improved ...
    if accuracy > best_accuracy:
        # Save the new model to harddisk.
        model.save(best_model_path)
        
        # Update the classification accuracy.
        best_accuracy = accuracy
        best_history = history

    # Delete the Keras model with these hyper-parameters from memory.
    del model
    
    # Clear the Keras session, otherwise it will keep adding new
    # models to the same TensorFlow graph each time we create
    # a model with a different set of hyper-parameters.
    tf.keras.backend.clear_session()
    tf.reset_default_graph()
    
    # NOTE: Scikit-optimize does minimization so it tries to
    # find a set of hyper-parameters with the LOWEST fitness-value.
    # Because we are interested in the HIGHEST classification
    # accuracy, we need to negate this number so it can be minimized.
    return -accuracy

# %%
i = 0
fitness(x=default_parameters)
# Out:
# index 0
# learning rate: 1.0e-03
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.4
# regularizer: 0.02
# kernel_size 4
# Highest validation accuracy: 60.47%
# Accuracy: 50.00%
# -0.5

# %%
i = 0
search_result = forest_minimize(func=fitness,
                            dimensions=dimensions,
                            acq_func='PI', # Expected Improvement.
                            n_calls=40,
                            x0=default_parameters)
# Out:
# index 0
# learning rate: 1.0e-03
# num_dense_nodes: 128
# num_rnn_layers: 0
# num_rnn_nodes: 128
# dropout_rate 0.4
# regularizer: 0.02
# kernel_size 4
# Highest validation accuracy: 83.72%
# Accuracy: 73.84%
#
#
# index 1
# learning rate: 2.6e-03
# num_dense_nodes: 135
# num_rnn_layers: 1
# num_rnn_nodes: 95
# dropout_rate 0.013023848529386265
# regularizer: 0.017197437140775818
# kernel_size 13
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 2
# learning rate: 1.2e-04
# num_dense_nodes: 103
# num_rnn_layers: 0
# num_rnn_nodes: 232
# dropout_rate 0.07287987530166674
# regularizer: 0.001403436926630012
# kernel_size 14
# Highest validation accuracy: 72.09%
# Accuracy: 55.23%
#
#
# index 3
# learning rate: 8.6e-04
# num_dense_nodes: 92
# num_rnn_layers: 1
# num_rnn_nodes: 101
# dropout_rate 0.0013024285644577807
# regularizer: 0.0038917204004587616
# kernel_size 6
# Highest validation accuracy: 81.98%
# Accuracy: 63.37%
#
#
# index 4
# learning rate: 6.7e-03
# num_dense_nodes: 220
# num_rnn_layers: 1
# num_rnn_nodes: 183
# dropout_rate 0.34485868431331784
# regularizer: 0.02999024448159864
# kernel_size 19
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 5
# learning rate: 2.8e-04
# num_dense_nodes: 76
# num_rnn_layers: 0
# num_rnn_nodes: 112
# dropout_rate 0.040020617843787694
# regularizer: 0.02291745869483545
# kernel_size 16
# Highest validation accuracy: 80.23%
# Accuracy: 63.95%
#
#
# index 6
# learning rate: 3.6e-04
# num_dense_nodes: 23
# num_rnn_layers: 1
# num_rnn_nodes: 233
# dropout_rate 0.2559968310084218
# regularizer: 0.018398316515972405
# kernel_size 11
# Highest validation accuracy: 55.81%
# Accuracy: 50.00%
#
#
# index 7
# learning rate: 3.1e-04
# num_dense_nodes: 250
# num_rnn_layers: 1
# num_rnn_nodes: 31
# dropout_rate 0.1804760036460422
# regularizer: 0.01159949787843987
# kernel_size 5
# Highest validation accuracy: 53.49%
# Accuracy: 50.00%
#
#
# index 8
# learning rate: 4.2e-03
# num_dense_nodes: 118
# num_rnn_layers: 0
# num_rnn_nodes: 80
# dropout_rate 0.2589741025725123
# regularizer: 0.004485773692955145
# kernel_size 6
# Highest validation accuracy: 85.47%
# Accuracy: 72.09%
#
#
# index 9
# learning rate: 4.7e-03
# num_dense_nodes: 102
# num_rnn_layers: 0
# num_rnn_nodes: 31
# dropout_rate 0.2475727243127464
# regularizer: 0.005886698138847455
# kernel_size 8
# Highest validation accuracy: 80.81%
# Accuracy: 70.93%
#
#
# index 10
# learning rate: 1.0e-04
# num_dense_nodes: 47
# num_rnn_layers: 0
# num_rnn_nodes: 103
# dropout_rate 0.03974366758329507
# regularizer: 0.027940621482670507
# kernel_size 9
# Highest validation accuracy: 65.70%
# Accuracy: 50.58%
#
#
# index 11
# learning rate: 1.0e-02
# num_dense_nodes: 173
# num_rnn_layers: 0
# num_rnn_nodes: 109
# dropout_rate 0.30699274793338904
# regularizer: 0.029342788661185174
# kernel_size 5
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 12
# learning rate: 7.8e-03
# num_dense_nodes: 107
# num_rnn_layers: 0
# num_rnn_nodes: 39
# dropout_rate 0.4686647971151713
# regularizer: 0.0038873041562251234
# kernel_size 5
# Highest validation accuracy: 81.98%
# Accuracy: 74.42%
#
#
# index 13
# learning rate: 9.5e-03
# num_dense_nodes: 119
# num_rnn_layers: 0
# num_rnn_nodes: 67
# dropout_rate 0.30608109608476103
# regularizer: 0.001189378856059125
# kernel_size 5
# Highest validation accuracy: 82.56%
# Accuracy: 70.35%
#
#
# index 14
# learning rate: 6.3e-03
# num_dense_nodes: 121
# num_rnn_layers: 0
# num_rnn_nodes: 66
# dropout_rate 0.4050519162990335
# regularizer: 0.0031836874654836166
# kernel_size 4
# Highest validation accuracy: 82.56%
# Accuracy: 73.26%
#
#
# index 15
# learning rate: 3.4e-03
# num_dense_nodes: 203
# num_rnn_layers: 0
# num_rnn_nodes: 55
# dropout_rate 0.40604280858192515
# regularizer: 0.003931486169941673
# kernel_size 4
# Highest validation accuracy: 83.72%
# Accuracy: 76.16%
#
#
# index 16
# learning rate: 2.2e-03
# num_dense_nodes: 198
# num_rnn_layers: 0
# num_rnn_nodes: 61
# dropout_rate 0.4083394143860956
# regularizer: 0.008578484482623362
# kernel_size 4
# Highest validation accuracy: 82.56%
# Accuracy: 75.58%
#
#
# index 17
# learning rate: 1.5e-03
# num_dense_nodes: 185
# num_rnn_layers: 0
# num_rnn_nodes: 42
# dropout_rate 0.4068865492173444
# regularizer: 0.013112845958022718
# kernel_size 3
# Highest validation accuracy: 82.56%
# Accuracy: 76.74%
#
#
# index 18
# learning rate: 2.6e-03
# num_dense_nodes: 195
# num_rnn_layers: 0
# num_rnn_nodes: 120
# dropout_rate 0.4976255141150841
# regularizer: 0.00822546358607252
# kernel_size 4
# Highest validation accuracy: 83.72%
# Accuracy: 73.26%
#
#
# index 19
# learning rate: 9.1e-04
# num_dense_nodes: 198
# num_rnn_layers: 0
# num_rnn_nodes: 26
# dropout_rate 0.44839441808824954
# regularizer: 0.017601737417841795
# kernel_size 4
# Highest validation accuracy: 83.14%
# Accuracy: 73.84%
#
#
# index 20
# learning rate: 7.3e-04
# num_dense_nodes: 183
# num_rnn_layers: 0
# num_rnn_nodes: 52
# dropout_rate 0.4181892827352452
# regularizer: 0.017485448007087356
# kernel_size 3
# Highest validation accuracy: 82.56%
# Accuracy: 75.58%
#
#
# index 21
# learning rate: 1.9e-03
# num_dense_nodes: 223
# num_rnn_layers: 0
# num_rnn_nodes: 28
# dropout_rate 0.4105198205071683
# regularizer: 0.022879946871507028
# kernel_size 2
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 22
# learning rate: 1.0e-03
# num_dense_nodes: 249
# num_rnn_layers: 0
# num_rnn_nodes: 27
# dropout_rate 0.407573610693482
# regularizer: 0.004799749991181986
# kernel_size 3
# Highest validation accuracy: 82.56%
# Accuracy: 76.16%
#
#
# index 23
# learning rate: 1.7e-03
# num_dense_nodes: 187
# num_rnn_layers: 0
# num_rnn_nodes: 33
# dropout_rate 0.40536459543660147
# regularizer: 0.01463331158530648
# kernel_size 3
# Highest validation accuracy: 84.30%
# Accuracy: 73.26%
#
#
# index 24
# learning rate: 1.4e-03
# num_dense_nodes: 238
# num_rnn_layers: 0
# num_rnn_nodes: 19
# dropout_rate 0.4617756378314677
# regularizer: 0.006864357278715091
# kernel_size 3
# Highest validation accuracy: 81.98%
# Accuracy: 77.33%
#
#
# index 25
# learning rate: 1.4e-03
# num_dense_nodes: 242
# num_rnn_layers: 0
# num_rnn_nodes: 218
# dropout_rate 0.4798993337735438
# regularizer: 0.0030421810152544116
# kernel_size 2
# Highest validation accuracy: 83.72%
# Accuracy: 70.93%
#
#
# index 26
# learning rate: 8.6e-04
# num_dense_nodes: 212
# num_rnn_layers: 0
# num_rnn_nodes: 47
# dropout_rate 0.4068211283325187
# regularizer: 0.015164827788629046
# kernel_size 2
# Highest validation accuracy: 83.14%
# Accuracy: 76.16%
#
#
# index 27
# learning rate: 3.0e-03
# num_dense_nodes: 204
# num_rnn_layers: 0
# num_rnn_nodes: 244
# dropout_rate 0.4577071356156182
# regularizer: 0.017996061905144748
# kernel_size 3
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 28
# learning rate: 4.7e-04
# num_dense_nodes: 223
# num_rnn_layers: 0
# num_rnn_nodes: 44
# dropout_rate 0.4300119017204303
# regularizer: 0.011470329888316907
# kernel_size 2
# Highest validation accuracy: 81.98%
# Accuracy: 76.16%
#
#
# index 29
# learning rate: 5.0e-05
# num_dense_nodes: 190
# num_rnn_layers: 0
# num_rnn_nodes: 30
# dropout_rate 0.4341695542653712
# regularizer: 0.008525071000759625
# kernel_size 2
# Highest validation accuracy: 58.72%
# Accuracy: 50.58%
#
#
# index 30
# learning rate: 7.6e-04
# num_dense_nodes: 70
# num_rnn_layers: 0
# num_rnn_nodes: 56
# dropout_rate 0.449922176299079
# regularizer: 0.012253020467055734
# kernel_size 3
# Highest validation accuracy: 81.98%
# Accuracy: 75.00%
#
#
# index 31
# learning rate: 5.4e-04
# num_dense_nodes: 228
# num_rnn_layers: 0
# num_rnn_nodes: 63
# dropout_rate 0.40526059046887175
# regularizer: 0.012250824566211477
# kernel_size 3
# Highest validation accuracy: 81.98%
# Accuracy: 77.33%
#
#
# index 32
# learning rate: 4.8e-04
# num_dense_nodes: 223
# num_rnn_layers: 0
# num_rnn_nodes: 76
# dropout_rate 0.461844005845918
# regularizer: 0.011938465800344092
# kernel_size 3
# Highest validation accuracy: 83.14%
# Accuracy: 76.16%
#
#
# index 33
# learning rate: 1.4e-03
# num_dense_nodes: 252
# num_rnn_layers: 0
# num_rnn_nodes: 33
# dropout_rate 0.40925665726872734
# regularizer: 0.013362044519567642
# kernel_size 3
# Highest validation accuracy: 83.14%
# Accuracy: 77.33%
#
#
# index 34
# learning rate: 8.3e-04
# num_dense_nodes: 240
# num_rnn_layers: 0
# num_rnn_nodes: 68
# dropout_rate 0.4007168131257726
# regularizer: 0.015465200468762357
# kernel_size 3
# Highest validation accuracy: 82.56%
# Accuracy: 76.74%
#
#
# index 35
# learning rate: 2.1e-03
# num_dense_nodes: 236
# num_rnn_layers: 0
# num_rnn_nodes: 55
# dropout_rate 0.4632158448896873
# regularizer: 0.01071221421101842
# kernel_size 4
# Highest validation accuracy: 84.30%
# Accuracy: 77.91%
#
#
# index 36
# learning rate: 7.9e-04
# num_dense_nodes: 252
# num_rnn_layers: 0
# num_rnn_nodes: 49
# dropout_rate 0.46959667953579004
# regularizer: 0.014000677848468254
# kernel_size 10
# Highest validation accuracy: 81.98%
# Accuracy: 68.02%
#
#
# index 37
# learning rate: 7.6e-03
# num_dense_nodes: 238
# num_rnn_layers: 0
# num_rnn_nodes: 38
# dropout_rate 0.4501985927140454
# regularizer: 0.010067387058456018
# kernel_size 4
# Highest validation accuracy: 49.42%
# Accuracy: 50.00%
#
#
# index 38
# learning rate: 1.4e-03
# num_dense_nodes: 240
# num_rnn_layers: 0
# num_rnn_nodes: 98
# dropout_rate 0.382422836131211
# regularizer: 0.011684584118868285
# kernel_size 3
# Highest validation accuracy: 82.56%
# Accuracy: 76.74%
#
#
# index 39
# learning rate: 1.4e-03
# num_dense_nodes: 231
# num_rnn_layers: 0
# num_rnn_nodes: 30
# dropout_rate 0.3676202841968399
# regularizer: 0.013770528163808173
# kernel_size 3
# Highest validation accuracy: 83.72%
# Accuracy: 77.33%

# %%
dim_names = ['learning_rate', 'num_dense_nodes', 'num_rnn_layers', 'num_rnn_nodes', 'dropout_rate', 'kernel_size', 'regularizer']
# best params
best_params = search_result.x
for k, v in zip(dim_names, best_params):
    print(k, ' -> ', v)

# highest accuracy value on test set
acc = round(-1 *search_result.fun, 2)
print('Best accuracy -> ', acc)
# Out:
# learning_rate  ->  0.0020831928571240603
# num_dense_nodes  ->  236
# num_rnn_layers  ->  0
# num_rnn_nodes  ->  55
# dropout_rate  ->  0.4632158448896873
# kernel_size  ->  4
# regularizer  ->  0.01071221421101842
# Best accuracy ->  0.78

# %%
plt.rcParams.update({'font.size': 10})
fig = plt.figure(figsize=(20, 20))
_ = plot_objective(result=search_result, dimensions=dim_names)

# %%
fig1 = plt.figure(figsize=(20, 20))
_ = plot_evaluations(search_result, dimensions=dim_names)

# %%
plt.rcParams.update({'font.size': 12})
fig2 = plt.figure(figsize=(15, 8))
_ = plot_convergence(search_result)
_ = plt.ylabel('Minimalna wartosć funkcji celu po n krokach')
_ = plt.xlabel('Liczba kroków algorytmu optymalizacji')
_ = plt.title('')

# %%
model = load_model(best_model_path)
print(model.summary())
predictions = model.predict(test_x)
predictions = (predictions > 0.5)
predictions = [int(pred) for pred in predictions]
prec = precision_score(test_y, predictions)
rec = recall_score(test_y, predictions)
acc = accuracy_score(test_y, predictions)

print(f"Accuracy: {round(acc * 100,2)}%")
print(f"precision: {round(prec * 100,2)}%")
print(f"recall: {round(rec * 100,2)}%")
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# layer_conv_1 (Conv1D)        (None, 60, 16)            2256
# _________________________________________________________________
# dropout (Dropout)            (None, 60, 16)            0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 30, 16)            0
# _________________________________________________________________
# layer_rnn_1 (CuDNNLSTM)      (None, 55)                16060
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 55)                0
# _________________________________________________________________
# layer_dense_1 (Dense)        (None, 236)               13216
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 236)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 237
# =================================================================
# Total params: 31,769
# Trainable params: 31,769
# Non-trainable params: 0
# _________________________________________________________________
# None
# Accuracy: 77.91%
# precision: 81.58%
# recall: 72.09%

# %%
plt.rcParams.update({'font.size': 14})
cm = confusion_matrix(y_target=test_y, 
                    y_predicted=predictions)

fig, ax = plot_confusion_matrix(conf_mat=cm,
                                class_names=['Spadek', 'Wzrost'],
                                figsize=(6,6))
_ = plt.ylabel('Prawdziwa etykieta')
_ = plt.xlabel('Przewidziana etykieta')

# %%
model.evaluate(test_x, test_y, steps=10)
# Out:
# WARNING:tensorflow:When passing input data as arrays, do not specify `steps_per_epoch`/`steps` argument. Please use `batch_size` instead.
# 10/10 [==============================] - 0s 12ms/step - loss: 0.6687 - acc: 0.7791
# [0.668749988079071, 0.7790698]

# %%
def plot_predictions(length=60):
    fig = plt.figure(figsize=(22,3))
    plt.plot(test_y[:length])
    plt.plot(np.array(predictions)[:length])
    plt.legend(['Rzeczywista', 'Predykcja'], loc=1)
    plt.xlabel('Krok czasowy')
    plt.ylabel('Klasa')
    plt.yticks([0, 1], ['Spadek', 'Wzrost'])

plot_predictions()

# %%
def plot_history(history):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch
    plt.figure(figsize=(10, 6))
    plt.xlabel('Epoch')
    plt.ylabel('Błąd')
    plt.plot(hist['epoch'], hist['loss'], linewidth=2, color='orange',
            label='Trening')
    plt.plot(hist['epoch'], hist['val_loss'], linewidth=2,
            label = 'Walidacja')
    plt.legend()

    plt.figure(figsize=(10, 6))
    plt.xlabel('Epoch')
    plt.ylabel('Dokładność')
    plt.plot(hist['epoch'], hist['acc'], linewidth=2, color='orange',
            label='Trening')
    plt.plot(hist['epoch'], hist['val_acc'], linewidth=2,
            label = 'Walidacja')
    plt.legend()

plot_history(best_history)

# %%
print(len(predictions))
save('predictions/conv_lstm.pickle', predictions)
# Out:
# 172
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
